# %%
import re
with open("test.txt" , "r") as f:
    lines = f.read()
content = lines.replace('\n',',')
content2 = content.replace(",,", "\n")

with open("test2.txt", "w") as f2:
    f2.write(content2)
